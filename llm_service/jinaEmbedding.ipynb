# %%
import requests
import json

# Jina AI 임베딩 API 엔드포인트
url = "https://api.jina.ai/v1/embeddings"

# 발급받은 API 키
api_key = "jina_1cd682089a3e4de2be54cb518cf6c044c1A-DBVF2NumyDd7UfmMxi9AIY8Y"

# 요청 헤더 설정
headers = {
    "Content-Type": "application/json",
    "Authorization": f"Bearer {api_key}"
}

data = {
    "model": "jina-clip-v2",
    "input": documents,
    "dimensions": 1024,
    "embedding_type": "float",  # 또는 'binary', 'base64' 등 필요에 따라 선택
    "normalized": True          # 벡터 정규화 여부
}
