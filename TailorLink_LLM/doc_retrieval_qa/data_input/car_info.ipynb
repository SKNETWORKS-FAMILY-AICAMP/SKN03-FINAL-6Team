# %%
import os
import pandas as pd

# 폴더 경로 설정
folder_path = "../data/genesis"  # 폴더 경로를 입력하세요

# 폴더 내 모든 CSV 파일 읽기
csv_files = [f for f in os.listdir(data_path) if f.endswith('.csv')]

# 데이터프레임 결합
df_list=[]
for file in csv_files:
    df = pd.read_csv(os.path.join(data_path, file))
    df['car_name'] = file.replace(' 파일.csv', '')
    df_list.append(df)

combined_df = pd.concat(df_list, ignore_index=True)  # 인덱스 무시하고 새로 생성
# combined_df = pd.concat([pd.read_csv(os.path.join(data_path, file)) for file in csv_files], ignore_index=True)
#
# # 결합된 데이터프레임 확인
combined_df
# Out:
#                               세부모델       연료 배터리 종류 배터리 제조사   배터리 전압    배터리 용량  \
# 0                      e-AWD (A/T)  전기(배터리)  리튬 이온    SK 온  522.7 V  87.2 kWh
# 1                      e-AWD (A/T)  전기(배터리)  리튬 이온    SK 온      NaN  77.4 kWh
# 2                        2WD (A/T)      가솔린    NaN     NaN      NaN       NaN
# 3                        AWD (A/T)      가솔린    NaN     NaN      NaN       NaN
# 4                스포츠 패키지 2WD (A/T)      가솔린    NaN     NaN      NaN       NaN
# 5                스포츠 패키지 AWD (A/T)      가솔린    NaN     NaN      NaN       NaN
# 6                        2WD (A/T)      가솔린    NaN     NaN      NaN       NaN
# 7                        AWD (A/T)      가솔린    NaN     NaN      NaN       NaN
# 8                스포츠 패키지 2WD (A/T)      가솔린    NaN     NaN      NaN       NaN
# 9                스포츠 패키지 AWD (A/T)      가솔린    NaN     NaN      NaN       NaN
# 10                 2WD (5인승) (A/T)      가솔린    NaN     NaN      NaN       NaN
# ...

# %%
import pymysql

try:
    # MySQL 연결
    connection = pymysql.connect(
        host='my-database.cbuom6aeon9v.ap-northeast-2.rds.amazonaws.com',        # MySQL 서버 주소 (localhost 또는 IP)
        user='admin',    # MySQL 사용자 이름
        password='tailorlink06',# MySQL 비밀번호
        database='mydatabase',# 사용할 데이터베이스 이름
        port=3306,               # MySQL 포트 (기본값: 3306)
        charset='utf8mb4',       # 문자셋 (한글 지원)
        cursorclass=pymysql.cursors.DictCursor # 결과를 딕셔너리 형태로 반환
    )

    print("MySQL에 성공적으로 연결되었습니다!")

    # 커서 객체 생성
    with connection.cursor() as cursor:
        # SQL 쿼리 실행
        cursor.execute("SELECT DATABASE();")
        result = cursor.fetchone()
        print("현재 사용 중인 데이터베이스:", result)

except pymysql.MySQLError as e:
    print("MySQL 연결 중 오류 발생:", e)

finally:
    # 연결 종료
    if connection:
        connection.close()
        print("MySQL 연결이 종료되었습니다.")
# Out:
# MySQL에 성공적으로 연결되었습니다!
# 현재 사용 중인 데이터베이스: {'DATABASE()': 'mydatabase'}
# MySQL 연결이 종료되었습니다.

# %%
import pandas as pd
from sqlalchemy import create_engine

# SQLAlchemy 엔진 생성
engine = create_engine('mysql+pymysql://admin:tailorlink06@my-database.cbuom6aeon9v.ap-northeast-2.rds.amazonaws.com:3306/mydatabase')



# 데이터프레임을 SQL 테이블로 저장
combined_df.to_sql(name='my_table', con=engine, if_exists='replace', index=False)

print("데이터가 성공적으로 데이터베이스에 저장되었습니다!")
# Out:
# 데이터가 성공적으로 데이터베이스에 저장되었습니다!
