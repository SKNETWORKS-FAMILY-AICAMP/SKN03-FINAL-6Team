# %%
client_id = "1c88a2fa-5208-45df-8930-63530b454779"
client_secret = "c2fb5ce6-2196-4bff-8540-b34509dae730"
access_token = "eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9..KabIhIZWpkFRxy5BzJ_NGJsp6PQFuh2K3mF576clR4ypIREJ_k4RlR-hrv09_jq9iznW84iRZ4hDFc3W2EZxAYLeVFFGthqowuV5sA-30lAP6kVNF8IMOPXxJIJFD9eJIL-xoZe5dzg-UuofXZqrW6cYpjUgCgOA59ynjffuXcPmajamuIJjKc5Czhm-KXzjhumuyVsdsidbUUEFZkZOY7RjaQS_u5jtc8WB0RWJzfC_u-h2_nBQaLW2Pyme71vD0940UZjPhkuiLTmM4bxCuxaH0sX8xM1P2S1jXQQnbS2yh5YVQEXCLBV0jnRKrUBANGOr7HHkTU-HFVExl5hz8w"

# %%
import base64
import requests
import urllib.parse

def publish_token(client_id, client_secret):
    try:
        # URL 및 요청 파라미터 설정
        oauth_domain = "https://oauth.codef.io"  # 실제 OAuth 도메인으로 변경
        get_token_endpoint = "/oauth/token"
        url = f"{oauth_domain}{get_token_endpoint}"
        params = "grant_type=client_credentials&scope=read"

        # 클라이언트 아이디와 시크릿코드 Base64 인코딩
        auth = f"{client_id}:{client_secret}"
        auth_encoded = base64.b64encode(auth.encode()).decode()  # Base64 인코딩
        auth_header = f"Basic {auth_encoded}"

        # 요청 헤더 설정
        headers = {
            "Content-Type": "application/x-www-form-urlencoded",
            "Authorization": auth_header
        }

        # POST 요청 전송
        response = requests.post(url, headers=headers, data=params)

        # 응답 코드 확인
        if response.status_code == 200:
            # JSON 응답 처리
            response_data = response.json()
            return response_data
        else:
            print(f"Error: HTTP {response.status_code}")
            print(response.text)
            return None

    except Exception as e:
        print(f"Exception occurred: {e}")
        return None

# %%
# 테스트용 실행 코드
if __name__ == "__main__":
    client_id = client_id       # 클라이언트 ID 입력
    client_secret = client_secret  # 클라이언트 시크릿 입력
    token_response = publish_token(client_id, client_secret)
    if token_response:
        print("Access Token Response:")
        print(token_response)
    else:
        print("Failed to get access token.")
# Out:
# Access Token Response:
# {'access_token': 'eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9..KabIhIZWpkFRxy5BzJ_NGJsp6PQFuh2K3mF576clR4ypIREJ_k4RlR-hrv09_jq9iznW84iRZ4hDFc3W2EZxAYLeVFFGthqowuV5sA-30lAP6kVNF8IMOPXxJIJFD9eJIL-xoZe5dzg-UuofXZqrW6cYpjUgCgOA59ynjffuXcPmajamuIJjKc5Czhm-KXzjhumuyVsdsidbUUEFZkZOY7RjaQS_u5jtc8WB0RWJzfC_u-h2_nBQaLW2Pyme71vD0940UZjPhkuiLTmM4bxCuxaH0sX8xM1P2S1jXQQnbS2yh5YVQEXCLBV0jnRKrUBANGOr7HHkTU-HFVExl5hz8w', 'token_type': 'bearer', 'expires_in': 604799, 'scope': 'read'}

# %%
print(access_token)
# Out:
# eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9..KabIhIZWpkFRxy5BzJ_NGJsp6PQFuh2K3mF576clR4ypIREJ_k4RlR-hrv09_jq9iznW84iRZ4hDFc3W2EZxAYLeVFFGthqowuV5sA-30lAP6kVNF8IMOPXxJIJFD9eJIL-xoZe5dzg-UuofXZqrW6cYpjUgCgOA59ynjffuXcPmajamuIJjKc5Czhm-KXzjhumuyVsdsidbUUEFZkZOY7RjaQS_u5jtc8WB0RWJzfC_u-h2_nBQaLW2Pyme71vD0940UZjPhkuiLTmM4bxCuxaH0sX8xM1P2S1jXQQnbS2yh5YVQEXCLBV0jnRKrUBANGOr7HHkTU-HFVExl5hz8w

# %%
import json

# %%
url = "https://development.codef.io/v1/kr/insurance/0003/damoa/session"
# 요청 헤더 설정
headers = {
    "Authorization": f"Bearer {access_token}",
    "Content-Type": "application/json"
}


data ={
    "organization": "0003",
    "address": "https://e-insmarket.or.kr"
}

response = requests.post(url, headers=headers, data=json.dumps(data))

# %%
# # 응답 처리
# if response.status_code == 200:
#     session_info = response.json()
#     session_id = session_info.get("sessionId")
#     print("세션 ID:", session_id)
# else:
#     print(f"오류 발생: {response.status_code} - {response.text}")

# %%
session_id = response.text

# %%
session_id
# Out:
# '%7B%22result%22%3A%7B%22code%22%3A%22CF-00000%22%2C%22extraMessage%22%3A%22%22%2C%22message%22%3A%22%EC%84%B1%EA%B3%B5%22%2C%22transactionId%22%3A%22675fc488ec822e4edd5c51a3%22%7D%2C%22data%22%3A%7B%22commDetailParam%22%3A%%3D%22%7D%7D'

# %%
import requests
import json

# CODEF API 엔드포인트 및 액세스 토큰 설정
url = "https://api.codef.io/v1/insurance/damoa/insurance-fee"
# access_token = "YOUR_ACCESS_TOKEN"  # 발급받은 액세스 토큰으로 대체하세요.

# 요청 헤더 설정
headers = {
    "Authorization": f"Bearer {access_token}",
    "Content-Type": "application/json"
}

# 요청 데이터 설정 (예시 데이터입니다. 실제 데이터로 대체하세요.)
data = {
    "organization": "0101",  # 보험사 코드
    "loginType": "4",  # 로그인 유형
    "identity": "9701311054411",  # 주민등록번호
    "birthDate": "19970131",  # 생년월일
    "identityEncYn": "Y",  # 주민등록번호 암호화 여부
    "userName": "김병수",  # 사용자 이름
    "phoneNo": "01083776180",  # 전화번호
    "telecom": "4",  # 통신사
    "timeOut": "300",  # 타임아웃 설정
    "detailParam": session_id,  # 상세 파라미터
    # "loginTypeLevel": "1",  # 로그인 레벨
    "optionCode": "61WI6",  # 옵션 코드
    "startDate": "20250101",  # 보험 시작일
    "brandCode": "001",  # 브랜드 코드
    "carName": "소나타",  # 차량 이름
    "regYear": "2020",  # 등록 연도
    "regYearDetail": "2020-01",  # 등록 연도 상세
    "detailCarName": "소나타 DN8",  # 상세 차량 이름
    "carNo": "12가3456",  # 차량 번호
    "baseCarType": "승용차",  # 기본 차량 유형
    "foreignCarYN": "N",  # 외제차 여부
    "basicAgreement1": "Y",  # 기본 약관 1
    "basicAgreement2": "Y",  # 기본 약관 2
    "basicAgreement3": "Y",  # 기본 약관 3
    "basicAgr3Detail": "상세내용",  # 기본 약관 3 상세
    "basicAgreement4": "Y",  # 기본 약관 4
    "basicAgreement5": "Y",  # 기본 약관 5
    "basicAgreement6": "Y",  # 기본 약관 6
    "basicAgreement7": "Y",  # 기본 약관 7
    "specialDc1": "N",  # 특별 할인 1
    "youngestBirth": "19900101",  # 가장 어린 운전자 생년월일
    "blackBoxDc": "Y",  # 블랙박스 할인 여부
    "purchaseYear": "2020",  # 구매 연도
    "purchaseAmt": "20000000",  # 구매 금액
    "driverRange": "1인",  # 운전자 범위
    "specialDcDetail1": "",  # 특별 할인 상세 1
    "specialDc2": "N",  # 특별 할인 2
    "specialDc3": "N",  # 특별 할인 3
    "specialDcDetail3": "",  # 특별 할인 상세 3
    "specialDc4": "N",  # 특별 할인 4
    "specialDc7": "N",  # 특별 할인 7
    "specialDcDetail71": "",  # 특별 할인 상세 7-1
    "specialDcDetail72": "",  # 특별 할인 상세 7-2
    "specialDc8": "N",  # 특별 할인 8
    "specialDc9": "N",  # 특별 할인 9
    "specialDc10": "N",  # 특별 할인 10
    "specialDcDetail10": "",  # 특별 할인 상세 10
    "specialDc11": "N",  # 특별 할인 11
    "specialDcDetail11": "",  # 특별 할인 상세 11
    "specialDc14": "N",  # 특별 할인 14
    "specialDcDetail14": "",  # 특별 할인 상세 14
    "specialDc12": "N",  # 특별 할인 12
    "specialDc13": "N",  # 특별 할인 13
    "specialDc15": "N",  # 특별 할인 15
    "specialDc16": "N",  # 특별 할인 16
    "type": "개인",  # 보험 유형
    "useType": "출퇴근용"  # 사용 용도
}

# API 요청 보내기
response = requests.post(url, headers=headers, data=json.dumps(data))

# 응답 처리
if response.status_code == 200:
    insurance_fee = response.json()
    print("보험료 계산 결과:", insurance_fee)
else:
    print(f"오류 발생: {response.status_code} - {response.text}")
